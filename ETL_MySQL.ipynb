# %% [markdown]
# # ETL

# %% [markdown]
# **In this phase of the project we will apply an ETL process on previously saved movie data. We will create new MySQL database after preparing the data for a relational database. Finally , we will export database to a .sql file in repository using MySQL.***

# %% [markdown]
# <h3>Specifications  - Database</h3>
# <ul>
# <li>
# <p><strong> Stakeholder wants you to leverage the cleaned data from the initial cleaning notebook. And wants you to create a MySQL database for them.</strong></p>
# </li>
# <li>
# <p>You should normalize the tables as best you can before adding them to your new database.</p>
# <ul>
# <li>Note: an important exception to their request is that they would like you to keep all of the data from the TMDB API in 1 table together (even though it will not be perfectly normalized).&nbsp;&nbsp;</li><li>You only need to keep the imdb_id, revenue, budget, and certification columns</li>
# </ul>
# </li>
# </ul>
# <h4>Required Transformation steps:</h4>
# <ul>
# <li>
# <p><strong>Normalize Genre:</strong></p>
# <ul>
# <li>Convert the single string of genres from title basics into 2 new tables.
# <ol>
# <li>
# <p><code>title_genres</code>:  with the columns:</p>
# <ul>
# <li>tconst</li>
# <li>genre_id</li>
# </ul>
# </li>
# <li>
# <p><code>genres</code>:</p>
# <ul>
# <li>genre_id</li>
# <li>genre_name</li>
# </ul>
# </li>
# </ol>
# </li>
# </ul>
# </li>
# <li>
# <ul>
# <li>For the <code>title basics</code> table, drop the following columns:
# <ul>
# <li>"original_title" (we will use the primary title column instead)</li>
# <li>"isAdult" ("Adult" will show up in the genres so this is redundant information).</li>
# <li>"titleType" (every row will be a movie).</li>
# <li>"genres" and other variants of genre (genre is now represented in the 2 new tables described above.</li>
# </ul>
# </li>
# <li>Do not include the <code>title_akas</code> table in your SQL database.
#
# </li>
# </ul>
# </li>
# </ul>
# <h4>MySQL Database Requirements</h4>
# <ul>
# <p>Create a new database on  MySQL server "movies".</p>
# </li>
# <li>
# <p>Make sure to have the following tables in "movies" database:</p>
# <ul>
# <li><code>title_basics</code></li>
# <li><code>title_ratings</code></li>
# <li><code>title_genres</code></li>
# <li><code>genres</code></li>
# <li><code>tmdb_data</code></li>
# </ul>
# </li>
# <li>
# <p>Set a Primary Key for each table.</p>
# </li>
# <li>
# </li>
# <li>
#
# <h2>Normalizing Genres</h2>
# <ul>
# <li>
# <ul>
# <li>Convert the single string of genres from title basics into 2 new tables.
# <ol>
# <li>
# <p><code>title_genres</code>:  with the columns:</p>
# <ul>
# <li>tconst</li>
# <li>genre_id</li>
# </ul>
# </li>
# <li>
# <p><code>genres</code>:</p>
# <ul>
# <li>genre_id</li>
# <li>genre_name</li>
# </ul>
# </li>
# </ol>
# </li>
# </ul>
# </li>
# <li>
# <p>Creating these tables will be a multi-step process.</p>
# <ol>
# <li>Getting a list of all individual genres.</li>
# <li>Create a new <code>title_genres</code> table with with the movie ids duplicated, once for each genre that a movie belongs to.</li>
# <li>Create a mapper dictionary with numeric ids for each genre.</li>
# <li>Use the mapper dictionary to replace the string genres in <code>title_genres</code> with numeric genre_ids.</li>
# <li>Convert the mapper dictionary into a final <code>genres</code> table with the numeric genre_id and the string genre.</li>
# </ol>
# </li>
# </ul>
#
# <ul>
# <li>To use a string column as our primary key, we will need to provide the SQL datatype schema of our columns when we create the table.
# <ul>
# <li>We will then use our <code>engine</code> to run the command to alter our table and add tconst as the primary key.</li>
# </ul>
# </li>
# </ul>
# <h4>1. Creating a dataype schema for <code>to_sql</code>:</h4>
# <ul>
# <li>
# <p><strong>Check the dtypes of your dataframe: (df.dtypes).</strong></p>
# <ul>
# <li>Create a dictionary with each column name as a key and the corresponding SQL datatype as the value.</li>
# </ul>
# </li>
# <li>
# <p><strong>Find the corresponding SQLalchemy datatype to use in the table below.</strong></p>
# </li>
# </ul>
# <table>
# <thead>
# <tr>
# <th>Pandas DataType</th>
# <th>SQLAlchemy DataType</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>int</td>
# <td>Integer()</td>
# </tr>
# <tr>
# <td>float</td>
# <td>Float()</td>
# </tr>
# <tr>
# <td>bool</td>
# <td>Boolean()</td>
# </tr>
# <tr>
# <td>object (for Primary Keys)</td>
# <td>String(max_str_len+1)</td>
# </tr>
# <tr>
# <td>object (for non-key columns)</td>
# <td>Text(max_str_len+1)</td>
# </tr>
# </tbody>
# </table>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os,json
import missingno as ms

plt.rcParams['figure.facecolor'] = 'white'

pd.set_option('display.max_columns',100)

# %%
## Folder to save IMDB files
FOLDER = "Data/"
# os.makedirs(FOLDER,exist_ok=True)
sorted(os.listdir(FOLDER))
# Out:
# ['.ipynb_checkpoints',
#  'final_tmdb_data_2000.csv.gz',
#  'final_tmdb_data_2001.csv.gz',
#  'final_tmdb_data_2002.csv.gz',
#  'final_tmdb_data_2003.csv.gz',
#  'final_tmdb_data_2004.csv.gz',
#  'final_tmdb_data_2005.csv.gz',
#  'final_tmdb_data_2006.csv.gz',
#  'final_tmdb_data_2007.csv.gz',
#  'final_tmdb_data_2008.csv.gz',
#  'final_tmdb_data_2009.csv.gz',
#  'final_tmdb_data_2010.csv.gz',
#  'final_tmdb_data_2011.csv.gz',
#  'final_tmdb_data_2012.csv.gz',
#  'final_tmdb_data_2013.csv.gz',
#  'final_tmdb_data_2014.csv.gz',
#  'final_tmdb_data_2015.csv.gz',
#  'final_tmdb_data_2016.csv.gz',
#  'final_tmdb_data_2017.csv.gz',
#  'final_tmdb_data_2018.csv.gz',
#  'final_tmdb_data_2019.csv.gz',
#  'final_tmdb_data_2020.csv.gz',
#  'final_tmdb_data_2021.csv.gz',
#  'movie_reviews.csv',
#  'nlp',
#  'processed-nlp-data.joblib',
#  'title_akas_cleaned.csv.gz',
#  'title_basics_cleaned.csv.gz',
#  'title_ratings_cleaned.csv.gz',
#  'tmdb_api_results_2000.json',
#  'tmdb_api_results_2001.json',
#  'tmdb_api_results_2002.json',
#  'tmdb_api_results_2003.json',
#  'tmdb_api_results_2004.json',
#  'tmdb_api_results_2005.json',
#  'tmdb_api_results_2006.json',
#  'tmdb_api_results_2007.json',
#  'tmdb_api_results_2008.json',
#  'tmdb_api_results_2009.json',
#  'tmdb_api_results_2010.json',
#  'tmdb_api_results_2011.json',
#  'tmdb_api_results_2012.json',
#  'tmdb_api_results_2013.json',
#  'tmdb_api_results_2014.json',
#  'tmdb_api_results_2015.json',
#  'tmdb_api_results_2016.json',
#  'tmdb_api_results_2017.json',
#  'tmdb_api_results_2018.json',
#  'tmdb_api_results_2019.json',
#  'tmdb_api_results_2020.json',
#  'tmdb_api_results_2021.json']

# %% [markdown]
# ## Extract: Loading Previous Data

# %% [markdown]
# ### Title Basics

# %%
## title basics
basics = pd.read_csv(f'{FOLDER}title_basics_cleaned.csv.gz',low_memory=False)
basics.info()
basics.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138722 entries, 0 to 138721
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          138722 non-null  object
#  1   titleType       138722 non-null  object
#  2   primaryTitle    138722 non-null  object
#  3   originalTitle   138722 non-null  object
#  4   isAdult         138722 non-null  int64
#  5   startYear       138722 non-null  float64
#  6   endYear         0 non-null       float64
#  7   runtimeMinutes  138722 non-null  int64
#  8   genres          138722 non-null  object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 9.5+ MB
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0082328     movie                                 Embodiment of Evil
# 4  tt0088751     movie                                  The Naked Monster
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                 The Other Side of the Wind        0     2018.0      NaN
# 3                      Encarnação do Demônio        0     2008.0      NaN
# 4                          The Naked Monster        0     2005.0      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3              94                  Horror
# 4             100    Comedy,Horror,Sci-Fi

# %% [markdown]
# ### Title Ratings

# %%
## title ratings
ratings = pd.read_csv(f"{FOLDER}/title_ratings_cleaned.csv.gz",low_memory=False)
ratings.info()
ratings.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 514241 entries, 0 to 514240
# Data columns (total 3 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tconst         514241 non-null  object
#  1   averageRating  514241 non-null  float64
#  2   numVotes       514241 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 11.8+ MB
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2007
# 1  tt0000002            5.8       269
# 2  tt0000005            6.2      2692
# 3  tt0000006            5.0       182
# 4  tt0000007            5.4       841

# %% [markdown]
# ### TMDB API Results

# %% [markdown]
# - Students should have combined the years 2000 and 2001 as part of Part 2. I forgot to do so so I am doing here

# %%
## INSTRUCTOR CODE (not taught to students)
import glob
q = f"{FOLDER}final*.csv.gz"
files = glob.glob(q)
files
# Out:
# ['Data/final_tmdb_data_2006.csv.gz',
#  'Data/final_tmdb_data_2018.csv.gz',
#  'Data/final_tmdb_data_2014.csv.gz',
#  'Data/final_tmdb_data_2008.csv.gz',
#  'Data/final_tmdb_data_2016.csv.gz',
#  'Data/final_tmdb_data_2004.csv.gz',
#  'Data/final_tmdb_data_2020.csv.gz',
#  'Data/final_tmdb_data_2000.csv.gz',
#  'Data/final_tmdb_data_2012.csv.gz',
#  'Data/final_tmdb_data_2010.csv.gz',
#  'Data/final_tmdb_data_2002.csv.gz',
#  'Data/final_tmdb_data_2019.csv.gz',
#  'Data/final_tmdb_data_2007.csv.gz',
#  'Data/final_tmdb_data_2015.csv.gz',
#  'Data/final_tmdb_data_2021.csv.gz',
#  'Data/final_tmdb_data_2017.csv.gz',
#  'Data/final_tmdb_data_2009.csv.gz',
#  'Data/final_tmdb_data_2005.csv.gz',
#  'Data/final_tmdb_data_2001.csv.gz',
#  'Data/final_tmdb_data_2013.csv.gz',
#  'Data/final_tmdb_data_2011.csv.gz',
#  'Data/final_tmdb_data_2003.csv.gz']

# %%
## INSTRUCTOR CODE (not taught to students)
df = pd.concat([pd.read_csv(f, lineterminator='\n') for f in files])
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98492 entries, 0 to 2483
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                98492 non-null  object
#  1   adult                  98470 non-null  float64
#  2   backdrop_path          58098 non-null  object
#  3   belongs_to_collection  5951 non-null   object
#  4   budget                 98470 non-null  float64
#  5   genres                 98470 non-null  object
#  6   homepage               18976 non-null  object
#  7   id                     98470 non-null  float64
#  8   original_language      98470 non-null  object
#  9   original_title         98470 non-null  object
#  10  overview               92913 non-null  object
#  11  popularity             98470 non-null  float64
#  12  poster_path            89808 non-null  object
#  13  production_companies   98470 non-null  object
#  14  production_countries   98470 non-null  object
#  15  release_date           96595 non-null  object
#  16  revenue                98470 non-null  float64
#  17  runtime                98470 non-null  float64
#  18  spoken_languages       98470 non-null  object
#  19  status                 98470 non-null  object
#  20  tagline                29424 non-null  object
#  21  title                  98470 non-null  object
#  22  video                  98470 non-null  float64
#  23  vote_average           98470 non-null  float64
#  24  vote_count             98470 non-null  float64
#  25  certification          15080 non-null  object
# dtypes: float64(9), object(17)
# memory usage: 20.3+ MB
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0103340    0.0  /rhdDnrUmGamF2kk9HZUgTApms2a.jpg                   NaN
# 2  tt0110476    0.0  /tGCeUKo6g74OehsgJ1rCtpi85aT.jpg                   NaN
# 3  tt0144280    0.0                               NaN                   NaN
# 4  tt0166871    0.0                               NaN                   NaN
#
#      budget                                             genres homepage  \
# 0       NaN                                                NaN      NaN
# 1       0.0                      [{'id': 18, 'name': 'Drama'}]      NaN
# 2       0.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
# 3  100000.0                                                 []      NaN
# 4       0.0  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...      NaN
#
#          id original_language                     original_title  \
# 0       NaN               NaN                                NaN
# 1  268253.0                pl  Życie za życie. Maksymilian Kolbe
# 2   63163.0                ru                 Мастер и Маргарита
# 3   30356.0                en      Whispers from a Shallow Grave
# 4  218584.0                pt       Viúva Rica Solteira Não Fica
#
#                                             overview  popularity  \
# 0                                                NaN         NaN
# 1  The story of catholic saint Maximilian Kolbe (...       2.794
# 2  Master is a talented writer in Moscow working ...       3.396
# 3  When a beautiful photo model disappears, polic...       1.662
# 4  Ana Catarina returns from Brazil with her fath...       1.148
#
#                         poster_path  \
# 0                               NaN
# 1  /40k326IEGBbAtt81yRR8HlmWSSL.jpg
# 2  /hvtnknTQBCKpDTXN2zqM5Nem5VE.jpg
# 3  /cjRqAh3u2Z0MBx9GtT1k7Z9732w.jpg
# 4  /nnwjvQI9TYhpVFWTrjF2tQd2Zql.jpg
#
#                                 production_companies  \
# 0                                                NaN
# 1  [{'id': 73037, 'logo_path': None, 'name': 'Stu...
# 2  [{'id': 22085, 'logo_path': None, 'name': 'Tvo...
# 3                                                 []
# 4  [{'id': 3289, 'logo_path': None, 'name': 'Clap...
#
#                                 production_countries release_date  revenue  \
# 0                                                NaN          NaN      NaN
# 1  [{'iso_3166_1': 'PL', 'name': 'Poland'}, {'iso...   1991-04-01      0.0
# 2           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1994-06-06      0.0
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   1997-01-01      0.0
# 4  [{'iso_3166_1': 'BR', 'name': 'Brazil'}, {'iso...   2006-11-16  56360.0
#
#    runtime                                   spoken_languages    status  \
# 0      NaN                                                NaN       NaN
# 1     90.0  [{'english_name': 'Italian', 'iso_639_1': 'it'...  Released
# 2    128.0  [{'english_name': 'Russian', 'iso_639_1': 'ru'...  Released
# 3     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4    135.0  [{'english_name': 'Portuguese', 'iso_639_1': '...  Released
#
#                   tagline                            title  video  \
# 0                     NaN                              NaN    NaN
# 1                     NaN  Life for Life: Maximilian Kolbe    0.0
# 2  Manuscripts don't burn         The Master and Margarita    0.0
# 3                     NaN    Whispers from a Shallow Grave    0.0
# 4                     NaN     Viúva Rica Solteira Não Fica    0.0
#
#    vote_average  vote_count certification
# 0           NaN         NaN           NaN
# 1         6.133        16.0           NaN
# 2         5.848        23.0           NaN
# 3         2.000         2.0           NaN
# 4         7.200         6.0           NaN

# %%
## Dropping Placeholder rows with id=0
df = df.loc[ df['imdb_id']!='0']
df
# Out:
#         imdb_id  adult                     backdrop_path  \
# 1     tt0103340    0.0  /rhdDnrUmGamF2kk9HZUgTApms2a.jpg
# 2     tt0110476    0.0  /tGCeUKo6g74OehsgJ1rCtpi85aT.jpg
# 3     tt0144280    0.0                               NaN
# 4     tt0166871    0.0                               NaN
# 5     tt0197633    0.0  /1hGrzTajJ5JC6VfPzrUj8Gj5t5k.jpg
# ...         ...    ...                               ...
# 2479  tt9496950    0.0  /gvMj3Si3v2kmgYnnuLQCxrjKSLw.jpg
# 2480  tt9641790    0.0                               NaN
# 2481  tt9697532    0.0                               NaN
# 2482  tt9795244    0.0                               NaN
# 2483  tt9799990    0.0  /x4z2x8gxwqyv7k5GcwgDBSYkmkm.jpg
#
#      belongs_to_collection    budget  \
# 1                      NaN       0.0
# 2                      NaN       0.0
# 3                      NaN  100000.0
# 4                      NaN       0.0
# 5                      NaN       0.0
# ...                    ...       ...
# 2479                   NaN       0.0
# 2480                   NaN     400.0
# 2481                   NaN       0.0
# 2482                   NaN    5500.0
# 2483                   NaN       0.0
#
#                                                  genres homepage         id  \
# 1                         [{'id': 18, 'name': 'Drama'}]      NaN   268253.0
# 2     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN    63163.0
# 3                                                    []      NaN    30356.0
# 4     [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...      NaN   218584.0
# 5     [{'id': 16, 'name': 'Animation'}, {'id': 35, '...      NaN    58520.0
# ...                                                 ...      ...        ...
# 2479                      [{'id': 18, 'name': 'Drama'}]      NaN   745968.0
# 2480  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...      NaN   253999.0
# 2481                     [{'id': 35, 'name': 'Comedy'}]      NaN   678197.0
# 2482                     [{'id': 27, 'name': 'Horror'}]      NaN  1018542.0
# 2483                     [{'id': 27, 'name': 'Horror'}]      NaN   580260.0
#
#      original_language                     original_title  \
# 1                   pl  Życie za życie. Maksymilian Kolbe
# 2                   ru                 Мастер и Маргарита
# 3                   en      Whispers from a Shallow Grave
# 4                   pt       Viúva Rica Solteira Não Fica
# 5                   en           Live Freaky! Die Freaky!
# ...                ...                                ...
# 2479                zh                               惊心动魄
# 2480                en                         Clearwater
# 2481                vi                   Một Giờ Làm Quan
# 2482                en                      Inside Inoxia
# 2483                it                       Il messaggio
#
#                                                overview  popularity  \
# 1     The story of catholic saint Maximilian Kolbe (...       2.794
# 2     Master is a talented writer in Moscow working ...       3.396
# 3     When a beautiful photo model disappears, polic...       1.662
# 4     Ana Catarina returns from Brazil with her fath...       1.148
# 5     In a distant future, a cult forms around the M...       1.451
# ...                                                 ...         ...
# 2479  The film is based on the theme of "SARS". The ...       0.840
# 2480  A woman has been abducted by the Clearwater ki...       0.600
# 2481  People think Han has become the boss;they  rea...       0.600
# 2482  Two young male metalheads get locked and trapp...       0.600
# 2483  A mysterious videotape seems to cause the deat...       0.600
#
#                            poster_path  \
# 1     /40k326IEGBbAtt81yRR8HlmWSSL.jpg
# 2     /hvtnknTQBCKpDTXN2zqM5Nem5VE.jpg
# 3     /cjRqAh3u2Z0MBx9GtT1k7Z9732w.jpg
# 4     /nnwjvQI9TYhpVFWTrjF2tQd2Zql.jpg
# 5     /eL3XPWneGaYWDwdKgJXE3nfOVkG.jpg
# ...                                ...
# 2479  /uRXvZUWP8xr3CtuFxjrYhdPKACz.jpg
# 2480  /nHGb9mGbU4Z1hjysxcmrKJO6BbH.jpg
# 2481  /r7OITGioF3iyvfgNfScXUzR3wXm.jpg
# 2482  /4klrK5MW6Xu2FIDL7H1K6aF5zTe.jpg
# 2483  /dueR2mf0FomPB7iATe2oNqj3FYm.jpg
#
#                                    production_companies  \
# 1     [{'id': 73037, 'logo_path': None, 'name': 'Stu...
# 2     [{'id': 22085, 'logo_path': None, 'name': 'Tvo...
# 3                                                    []
# 4     [{'id': 3289, 'logo_path': None, 'name': 'Clap...
# 5                                                    []
# ...                                                 ...
# 2479                                                 []
# 2480  [{'id': 174685, 'logo_path': None, 'name': 'Li...
# 2481                                                 []
# 2482  [{'id': 181413, 'logo_path': None, 'name': 'Te...
# 2483                                                 []
#
#                                    production_countries release_date  revenue  \
# 1     [{'iso_3166_1': 'PL', 'name': 'Poland'}, {'iso...   1991-04-01      0.0
# 2              [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1994-06-06      0.0
# 3     [{'iso_3166_1': 'US', 'name': 'United States o...   1997-01-01      0.0
# 4     [{'iso_3166_1': 'BR', 'name': 'Brazil'}, {'iso...   2006-11-16  56360.0
# 5     [{'iso_3166_1': 'US', 'name': 'United States o...   2006-01-31      0.0
# ...                                                 ...          ...      ...
# 2479                                                 []   2003-07-17      0.0
# 2480                                                 []   2003-06-10      0.0
# 2481          [{'iso_3166_1': 'VN', 'name': 'Vietnam'}]   2003-01-12      0.0
# 2482                                                 []   2003-07-14      0.0
# 2483                                                 []   2003-01-01      0.0
#
#       runtime                                   spoken_languages    status  \
# 1        90.0  [{'english_name': 'Italian', 'iso_639_1': 'it'...  Released
# 2       128.0  [{'english_name': 'Russian', 'iso_639_1': 'ru'...  Released
# 3        90.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4       135.0  [{'english_name': 'Portuguese', 'iso_639_1': '...  Released
# 5        75.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...       ...                                                ...       ...
# 2479     95.0  [{'english_name': 'Mandarin', 'iso_639_1': 'zh...  Released
# 2480     60.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2481     86.0  [{'english_name': 'Vietnamese', 'iso_639_1': '...  Released
# 2482     85.0                                                 []  Released
# 2483      0.0  [{'english_name': 'Italian', 'iso_639_1': 'it'...  Released
#
#                      tagline                            title  video  \
# 1                        NaN  Life for Life: Maximilian Kolbe    0.0
# 2     Manuscripts don't burn         The Master and Margarita    0.0
# 3                        NaN    Whispers from a Shallow Grave    0.0
# 4                        NaN     Viúva Rica Solteira Não Fica    0.0
# 5                        NaN         Live Freaky! Die Freaky!    0.0
# ...                      ...                              ...    ...
# 2479                     NaN                   A SARS Journey    0.0
# 2480                     NaN                       Clearwater    0.0
# 2481                     NaN          Being a Boss in an Hour    0.0
# 2482                     NaN                    Inside Inoxia    0.0
# 2483                     NaN                     Il messaggio    0.0
#
#       vote_average  vote_count certification
# 1            6.133        16.0           NaN
# 2            5.848        23.0           NaN
# 3            2.000         2.0           NaN
# 4            7.200         6.0           NaN
# 5            3.800         8.0            NR
# ...            ...         ...           ...
# 2479         0.000         0.0           NaN
# 2480         0.000         0.0           NaN
# 2481         0.000         0.0           NaN
# 2482        10.000         1.0           NaN
# 2483         2.000         2.0           NaN
#
# [98470 rows x 26 columns]

# %% [markdown]
# # Transform

# %% [markdown]
# ## basics

# %% [markdown]
# - normalize and separate genre
# - "original_title" (we will use the primary title column instead)
# - "isAdult" ("Adult" will show up in the genres so this is redundant information).
# - "titleType" (every row will be a movie).
# - "genres" and other variants of genre (genre is now represented in the 2 new tables described above.

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138722 entries, 0 to 138721
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          138722 non-null  object
#  1   titleType       138722 non-null  object
#  2   primaryTitle    138722 non-null  object
#  3   originalTitle   138722 non-null  object
#  4   isAdult         138722 non-null  int64
#  5   startYear       138722 non-null  float64
#  6   endYear         0 non-null       float64
#  7   runtimeMinutes  138722 non-null  int64
#  8   genres          138722 non-null  object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 9.5+ MB

# %%
cols_to_drop = ['originalTitle','isAdult','titleType','endYear'] #endYear not req'd
basics = basics.drop(columns=cols_to_drop)
basics
# Out:
#            tconst                                       primaryTitle  \
# 0       tt0035423                                     Kate & Leopold
# 1       tt0062336  The Tango of the Widower and Its Distorting Mi...
# 2       tt0069049                         The Other Side of the Wind
# 3       tt0082328                                 Embodiment of Evil
# 4       tt0088751                                  The Naked Monster
# ...           ...                                                ...
# 138717  tt9916190                                          Safeguard
# 138718  tt9916270                           Il talento del calabrone
# 138719  tt9916362                                              Coven
# 138720  tt9916538                                Kuambil Lagi Hatiku
# 138721  tt9916730                                             6 Gunn
#
#         startYear  runtimeMinutes                     genres
# 0          2001.0             118     Comedy,Fantasy,Romance
# 1          2020.0              70                      Drama
# 2          2018.0             122                      Drama
# 3          2008.0              94                     Horror
# 4          2005.0             100       Comedy,Horror,Sci-Fi
# ...           ...             ...                        ...
# 138717     2020.0              95  Action,Adventure,Thriller
# 138718     2020.0              84                   Thriller
# 138719     2020.0              92              Drama,History
# 138720     2019.0             123                      Drama
# 138721     2017.0             116                      Drama
#
# [138722 rows x 5 columns]

# %% [markdown]
# ### Normalizing Genre

# %%
## Fill Missing Genres 
## Create a new column with the single-string genres as a list of strings
basics['genres_split'] = basics['genres'].str.split(',')
basics
# Out:
#            tconst                                       primaryTitle  \
# 0       tt0035423                                     Kate & Leopold
# 1       tt0062336  The Tango of the Widower and Its Distorting Mi...
# 2       tt0069049                         The Other Side of the Wind
# 3       tt0082328                                 Embodiment of Evil
# 4       tt0088751                                  The Naked Monster
# ...           ...                                                ...
# 138717  tt9916190                                          Safeguard
# 138718  tt9916270                           Il talento del calabrone
# 138719  tt9916362                                              Coven
# 138720  tt9916538                                Kuambil Lagi Hatiku
# 138721  tt9916730                                             6 Gunn
#
#         startYear  runtimeMinutes                     genres  \
# 0          2001.0             118     Comedy,Fantasy,Romance
# 1          2020.0              70                      Drama
# 2          2018.0             122                      Drama
# 3          2008.0              94                     Horror
# 4          2005.0             100       Comedy,Horror,Sci-Fi
# ...           ...             ...                        ...
# 138717     2020.0              95  Action,Adventure,Thriller
# 138718     2020.0              84                   Thriller
# 138719     2020.0              92              Drama,History
# 138720     2019.0             123                      Drama
# 138721     2017.0             116                      Drama
#
#                          genres_split
# 0          [Comedy, Fantasy, Romance]
# 1                             [Drama]
# 2                             [Drama]
# 3                            [Horror]
# 4            [Comedy, Horror, Sci-Fi]
# ...                               ...
# 138717  [Action, Adventure, Thriller]
# 138718                     [Thriller]
# 138719               [Drama, History]
# 138720                        [Drama]
# 138721                        [Drama]
#
# [138722 rows x 6 columns]

# %%
## Explode the dataframe to make each genre into a separate row
exploded_genres = basics.explode('genres_split')
exploded_genres
# Out:
#            tconst                                       primaryTitle  \
# 0       tt0035423                                     Kate & Leopold
# 0       tt0035423                                     Kate & Leopold
# 0       tt0035423                                     Kate & Leopold
# 1       tt0062336  The Tango of the Widower and Its Distorting Mi...
# 2       tt0069049                         The Other Side of the Wind
# ...           ...                                                ...
# 138718  tt9916270                           Il talento del calabrone
# 138719  tt9916362                                              Coven
# 138719  tt9916362                                              Coven
# 138720  tt9916538                                Kuambil Lagi Hatiku
# 138721  tt9916730                                             6 Gunn
#
#         startYear  runtimeMinutes                  genres genres_split
# 0          2001.0             118  Comedy,Fantasy,Romance       Comedy
# 0          2001.0             118  Comedy,Fantasy,Romance      Fantasy
# 0          2001.0             118  Comedy,Fantasy,Romance      Romance
# 1          2020.0              70                   Drama        Drama
# 2          2018.0             122                   Drama        Drama
# ...           ...             ...                     ...          ...
# 138718     2020.0              84                Thriller     Thriller
# 138719     2020.0              92           Drama,History        Drama
# 138719     2020.0              92           Drama,History      History
# 138720     2019.0             123                   Drama        Drama
# 138721     2017.0             116                   Drama        Drama
#
# [241997 rows x 6 columns]

# %% [markdown]
# #### Create title_genres Table - title_genres
# tconst: GenreID

# %%
## Save just tconst and genres_split as new df
title_genres = exploded_genres[['tconst','genres_split']].copy()
title_genres.head()
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance
# 1  tt0062336        Drama
# 2  tt0069049        Drama

# %% [markdown]
# #### Replacing Text Genres with Integer IDs

# %%
## Getting unique list of genres
unique_genres = sorted(title_genres['genres_split'].unique())
unique_genres
# Out:
# ['Action',
#  'Adult',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Game-Show',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'News',
#  'Reality-TV',
#  'Romance',
#  'Sci-Fi',
#  'Sport',
#  'Talk-Show',
#  'Thriller',
#  'War',
#  'Western']

# %%
## Make a dictionary with list of unique genres as the key and the new iteger id as vlaues
genre_id_map = dict(zip(unique_genres, range(len(unique_genres))))
genre_id_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Sport': 20,
#  'Talk-Show': 21,
#  'Thriller': 22,
#  'War': 23,
#  'Western': 24}

# %% [markdown]
# #### Replacing Values in title_genres Table with Genre ID

# %%
## Use .map or .replace with our genre_id_map dictionary
title_genres['Genre_ID'] = title_genres['genres_split'].replace(genre_id_map)

## Drop the original genre column
title_genres.drop(columns=['genres_split'],inplace=True)
title_genres
# Out:
#            tconst  Genre_ID
# 0       tt0035423         5
# 0       tt0035423         9
# 0       tt0035423        18
# 1       tt0062336         7
# 2       tt0069049         7
# ...           ...       ...
# 138718  tt9916270        22
# 138719  tt9916362         7
# 138719  tt9916362        11
# 138720  tt9916538         7
# 138721  tt9916730         7
#
# [241997 rows x 2 columns]

# %% [markdown]
# #### Create `genres` table
# - Genre : Genre_ID

# %%
## Manaully make dataframe with named cols from the .keyd and .values
genre_lookup = pd.DataFrame({'Genre_Name': genre_id_map.keys(),
                             'Genre_ID':genre_id_map.values()})
genre_lookup.head()
# Out:
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
## Dropping original genre columns 
basics = basics.drop(columns=['genres','genres_split'])
basics
# Out:
#            tconst                                       primaryTitle  \
# 0       tt0035423                                     Kate & Leopold
# 1       tt0062336  The Tango of the Widower and Its Distorting Mi...
# 2       tt0069049                         The Other Side of the Wind
# 3       tt0082328                                 Embodiment of Evil
# 4       tt0088751                                  The Naked Monster
# ...           ...                                                ...
# 138717  tt9916190                                          Safeguard
# 138718  tt9916270                           Il talento del calabrone
# 138719  tt9916362                                              Coven
# 138720  tt9916538                                Kuambil Lagi Hatiku
# 138721  tt9916730                                             6 Gunn
#
#         startYear  runtimeMinutes
# 0          2001.0             118
# 1          2020.0              70
# 2          2018.0             122
# 3          2008.0              94
# 4          2005.0             100
# ...           ...             ...
# 138717     2020.0              95
# 138718     2020.0              84
# 138719     2020.0              92
# 138720     2019.0             123
# 138721     2017.0             116
#
# [138722 rows x 4 columns]

# %% [markdown]
# # LOAD

# %% [markdown]
# ## Connect to MySQL

# %%
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
from sqlalchemy_utils import create_database, database_exists
from sqlalchemy.types import *
from urllib.parse import quote_plus as urlquote

# %%
## Getting mysql server password
import json
with open('/Users/purvikansara/.secret/mysql.json') as f:
    login = json.load(f)

login.keys()
# Out:
# dict_keys(['username', 'password'])

# %%
## create a new movies database
connect_str = f"mysql+pymysql://{login['username']}:{urlquote(login['password'])}@localhost/movies"

# %%
## Check if database exists, if not, create it
if database_exists(connect_str) == False:
    print("Creating the database.")
    create_database(connect_str)
else:
    print('The database already exists.')
# Out:
# The database already exists.

# %%
## create engine
engine = create_engine(connect_str)

# %%
## Test your connection by checking for any tables that exist (there should be none at this point)
q = """SHOW TABLES;"""
tables = pd.read_sql(q, engine)
tables
# Out:
#   Tables_in_movies
# 0           genres
# 1     title_basics
# 2      title_genre
# 3     title_genres
# 4    title_ratings
# 5        tmdb_data
# 6    tmdb_data_aab
# 7    tmdb_data_mvp

# %% [markdown]
# ### Saving`title_basics` to db

# %%
## saving text length
key_len = basics['tconst'].map(len).max()
title_len = basics['primaryTitle'].map(len).max()
key_len, title_len
# Out:
# (10, 242)

# %%
basics_schema = {
    "tconst": String(key_len+1), 
    "primaryTitle": Text(title_len+1),
    'startYear':Float(),
    'runtimeMinutes':Integer()
    }
basics_schema
# Out:
# {'tconst': String(length=11),
#  'primaryTitle': Text(length=243),
#  'startYear': Float(),
#  'runtimeMinutes': Integer()}

# %%
basics
# Out:
#            tconst                                       primaryTitle  \
# 0       tt0035423                                     Kate & Leopold
# 1       tt0062336  The Tango of the Widower and Its Distorting Mi...
# 2       tt0069049                         The Other Side of the Wind
# 3       tt0082328                                 Embodiment of Evil
# 4       tt0088751                                  The Naked Monster
# ...           ...                                                ...
# 138717  tt9916190                                          Safeguard
# 138718  tt9916270                           Il talento del calabrone
# 138719  tt9916362                                              Coven
# 138720  tt9916538                                Kuambil Lagi Hatiku
# 138721  tt9916730                                             6 Gunn
#
#         startYear  runtimeMinutes
# 0          2001.0             118
# 1          2020.0              70
# 2          2018.0             122
# 3          2008.0              94
# 4          2005.0             100
# ...           ...             ...
# 138717     2020.0              95
# 138718     2020.0              84
# 138719     2020.0              92
# 138720     2019.0             123
# 138721     2017.0             116
#
# [138722 rows x 4 columns]

# %%
## Saving basics as table with schema,
basics.to_sql('title_basics',engine,dtype=basics_schema,if_exists='replace',index=False)

## setting title basics as the primary key
engine.execute('ALTER TABLE title_basics ADD PRIMARY KEY (`tconst`);')

# %%
## query first rows 
q = """SELECT * FROM title_basics LIMIT 5"""
pd.read_sql(q,engine)
# Out:
#       tconst                                       primaryTitle  startYear  \
# 0  tt0035423                                     Kate & Leopold     2001.0
# 1  tt0062336  The Tango of the Widower and Its Distorting Mi...     2020.0
# 2  tt0069049                         The Other Side of the Wind     2018.0
# 3  tt0082328                                 Embodiment of Evil     2008.0
# 4  tt0088751                                  The Naked Monster     2005.0
#
#    runtimeMinutes
# 0             118
# 1              70
# 2             122
# 3              94
# 4             100

# %% [markdown]
# ### Saving Genre Tables

# %% [markdown]
# #### Saving genre_lookup

# %%
genre_lookup.head()
# Out:
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
## Primary key is Genre_ID
genre_lookup.to_sql('genres',engine,index=False, if_exists='replace')

engine.execute('ALTER TABLE genres ADD PRIMARY KEY (`Genre_ID`);')

# %%
q = """SELECT * FROM genres LIMIT 5"""
pd.read_sql(q,engine)
# Out:
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %% [markdown]
# #### Saving `title_genres` table

# %%
## NO PRIMARY KEY - DUPLCIATE VALUES
title_genres.to_sql('title_genres',engine,index=False,
                    if_exists='replace' )

# engine.execute('ALTER TABLE title_genres ADD PRIMARY KEY (`tconst`);')
# Out:
# 241997

# %%
q = """SELECT * FROM title_genres LIMIT 5"""
pd.read_sql(q,engine)
# Out:
#       tconst  Genre_ID
# 0  tt0035423         5
# 1  tt0035423         9
# 2  tt0035423        18
# 3  tt0062336         7
# 4  tt0069049         7

# %% [markdown]
# ### Saving `title_ratings`

# %%
ratings_schema = {'tconst':String(key_len+1), 
                 'averageRating':Float(),
                 'numVotes':Integer()}#get_schema(ratings)
ratings_schema
# Out:
# {'tconst': String(length=11), 'averageRating': Float(), 'numVotes': Integer()}

# %%
ratings.to_sql('title_ratings',engine,if_exists='replace',index=False,
              dtype=ratings_schema)
engine.execute("ALTER TABLE title_ratings ADD PRIMARY KEY (`tconst`)")

# %%
q = """SELECT * FROM title_ratings LIMIT 5"""
pd.read_sql(q,engine)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2007
# 1  tt0000002            5.8       269
# 2  tt0000005            6.2      2692
# 3  tt0000006            5.0       182
# 4  tt0000007            5.4       841

# %% [markdown]
# ### Saving TMDB API Data

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98470 entries, 1 to 2483
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                98470 non-null  object
#  1   adult                  98470 non-null  float64
#  2   backdrop_path          58098 non-null  object
#  3   belongs_to_collection  5951 non-null   object
#  4   budget                 98470 non-null  float64
#  5   genres                 98470 non-null  object
#  6   homepage               18976 non-null  object
#  7   id                     98470 non-null  float64
#  8   original_language      98470 non-null  object
#  9   original_title         98470 non-null  object
#  10  overview               92913 non-null  object
#  11  popularity             98470 non-null  float64
#  12  poster_path            89808 non-null  object
#  13  production_companies   98470 non-null  object
#  14  production_countries   98470 non-null  object
#  15  release_date           96595 non-null  object
#  16  revenue                98470 non-null  float64
#  17  runtime                98470 non-null  float64
#  18  spoken_languages       98470 non-null  object
#  19  status                 98470 non-null  object
#  20  tagline                29424 non-null  object
#  21  title                  98470 non-null  object
#  22  video                  98470 non-null  float64
#  23  vote_average           98470 non-null  float64
#  24  vote_count             98470 non-null  float64
#  25  certification          15080 non-null  object
# dtypes: float64(9), object(17)
# memory usage: 20.3+ MB
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 1  tt0103340    0.0  /rhdDnrUmGamF2kk9HZUgTApms2a.jpg                   NaN
# 2  tt0110476    0.0  /tGCeUKo6g74OehsgJ1rCtpi85aT.jpg                   NaN
# 3  tt0144280    0.0                               NaN                   NaN
# 4  tt0166871    0.0                               NaN                   NaN
# 5  tt0197633    0.0  /1hGrzTajJ5JC6VfPzrUj8Gj5t5k.jpg                   NaN
#
#      budget                                             genres homepage  \
# 1       0.0                      [{'id': 18, 'name': 'Drama'}]      NaN
# 2       0.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
# 3  100000.0                                                 []      NaN
# 4       0.0  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...      NaN
# 5       0.0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...      NaN
#
#          id original_language                     original_title  \
# 1  268253.0                pl  Życie za życie. Maksymilian Kolbe
# 2   63163.0                ru                 Мастер и Маргарита
# 3   30356.0                en      Whispers from a Shallow Grave
# 4  218584.0                pt       Viúva Rica Solteira Não Fica
# 5   58520.0                en           Live Freaky! Die Freaky!
#
#                                             overview  popularity  \
# 1  The story of catholic saint Maximilian Kolbe (...       2.794
# 2  Master is a talented writer in Moscow working ...       3.396
# 3  When a beautiful photo model disappears, polic...       1.662
# 4  Ana Catarina returns from Brazil with her fath...       1.148
# 5  In a distant future, a cult forms around the M...       1.451
#
#                         poster_path  \
# 1  /40k326IEGBbAtt81yRR8HlmWSSL.jpg
# 2  /hvtnknTQBCKpDTXN2zqM5Nem5VE.jpg
# 3  /cjRqAh3u2Z0MBx9GtT1k7Z9732w.jpg
# 4  /nnwjvQI9TYhpVFWTrjF2tQd2Zql.jpg
# 5  /eL3XPWneGaYWDwdKgJXE3nfOVkG.jpg
#
#                                 production_companies  \
# 1  [{'id': 73037, 'logo_path': None, 'name': 'Stu...
# 2  [{'id': 22085, 'logo_path': None, 'name': 'Tvo...
# 3                                                 []
# 4  [{'id': 3289, 'logo_path': None, 'name': 'Clap...
# 5                                                 []
#
#                                 production_countries release_date  revenue  \
# 1  [{'iso_3166_1': 'PL', 'name': 'Poland'}, {'iso...   1991-04-01      0.0
# 2           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1994-06-06      0.0
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   1997-01-01      0.0
# 4  [{'iso_3166_1': 'BR', 'name': 'Brazil'}, {'iso...   2006-11-16  56360.0
# 5  [{'iso_3166_1': 'US', 'name': 'United States o...   2006-01-31      0.0
#
#    runtime                                   spoken_languages    status  \
# 1     90.0  [{'english_name': 'Italian', 'iso_639_1': 'it'...  Released
# 2    128.0  [{'english_name': 'Russian', 'iso_639_1': 'ru'...  Released
# 3     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4    135.0  [{'english_name': 'Portuguese', 'iso_639_1': '...  Released
# 5     75.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                   tagline                            title  video  \
# 1                     NaN  Life for Life: Maximilian Kolbe    0.0
# 2  Manuscripts don't burn         The Master and Margarita    0.0
# 3                     NaN    Whispers from a Shallow Grave    0.0
# 4                     NaN     Viúva Rica Solteira Não Fica    0.0
# 5                     NaN         Live Freaky! Die Freaky!    0.0
#
#    vote_average  vote_count certification
# 1         6.133        16.0           NaN
# 2         5.848        23.0           NaN
# 3         2.000         2.0           NaN
# 4         7.200         6.0           NaN
# 5         3.800         8.0            NR

# %%
## Keeping some columns
cols_to_keep = ['imdb_id','budget','revenue','certification',
                'original_language']
tmdb = df[cols_to_keep]
tmdb
# Out:
#         imdb_id    budget  revenue certification original_language
# 1     tt0103340       0.0      0.0           NaN                pl
# 2     tt0110476       0.0      0.0           NaN                ru
# 3     tt0144280  100000.0      0.0           NaN                en
# 4     tt0166871       0.0  56360.0           NaN                pt
# 5     tt0197633       0.0      0.0            NR                en
# ...         ...       ...      ...           ...               ...
# 2479  tt9496950       0.0      0.0           NaN                zh
# 2480  tt9641790     400.0      0.0           NaN                en
# 2481  tt9697532       0.0      0.0           NaN                vi
# 2482  tt9795244    5500.0      0.0           NaN                en
# 2483  tt9799990       0.0      0.0           NaN                it
#
# [98470 rows x 5 columns]

# %%
tmdb.isna().sum()
# Out:
# imdb_id                  0
# budget                   0
# revenue                  0
# certification        83390
# original_language        0
# dtype: int64

# %%
tmdb
# Out:
#         imdb_id    budget  revenue certification original_language
# 1     tt0103340       0.0      0.0           NaN                pl
# 2     tt0110476       0.0      0.0           NaN                ru
# 3     tt0144280  100000.0      0.0           NaN                en
# 4     tt0166871       0.0  56360.0           NaN                pt
# 5     tt0197633       0.0      0.0            NR                en
# ...         ...       ...      ...           ...               ...
# 2479  tt9496950       0.0      0.0           NaN                zh
# 2480  tt9641790     400.0      0.0           NaN                en
# 2481  tt9697532       0.0      0.0           NaN                vi
# 2482  tt9795244    5500.0      0.0           NaN                en
# 2483  tt9799990       0.0      0.0           NaN                it
#
# [98470 rows x 5 columns]

# %%
## saving text length
key_len = tmdb['imdb_id'].map(len).max()
cert_len = tmdb['certification'].fillna('').map(len).max()
lang_len = tmdb['original_language'].map(len).max()

key_len, cert_len,lang_len
# Out:
# (10, 7, 2)

# %%
## saving schema
api_data_schema = {'imdb_id':String(key_len+1), 
                 'budget':Float(),
                   'revenue':Float(),
                 'certification':Text(cert_len+1),
                  'original_language':Text(lang_len+1)}
api_data_schema
# Out:
# {'imdb_id': String(length=11),
#  'budget': Float(),
#  'revenue': Float(),
#  'certification': Text(length=8),
#  'original_language': Text(length=3)}

# %%
tmdb = tmdb.drop_duplicates(subset=['imdb_id'])

# %%
# saving tmdb version
## Primary key is Genre_ID
tmdb.to_sql('tmdb_data',engine, index=False,dtype=api_data_schema, if_exists='replace')

engine.execute('ALTER TABLE tmdb_data ADD PRIMARY KEY (`imdb_id`);')

# %%
q = """SELECT * FROM tmdb_data LIMIT 5"""
pd.read_sql(q,engine)
# Out:
#      imdb_id      budget     revenue certification original_language
# 0  tt0035423  48000000.0  76019000.0         PG-13                en
# 1  tt0062336         0.0         0.0          None                es
# 2  tt0069049  12000000.0         0.0             R                en
# 3  tt0079644         0.0         0.0          None                id
# 4  tt0088751    350000.0         0.0          None                en

# %%
df.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 1  tt0103340    0.0  /rhdDnrUmGamF2kk9HZUgTApms2a.jpg                   NaN
# 2  tt0110476    0.0  /tGCeUKo6g74OehsgJ1rCtpi85aT.jpg                   NaN
# 3  tt0144280    0.0                               NaN                   NaN
# 4  tt0166871    0.0                               NaN                   NaN
# 5  tt0197633    0.0  /1hGrzTajJ5JC6VfPzrUj8Gj5t5k.jpg                   NaN
#
#      budget                                             genres homepage  \
# 1       0.0                      [{'id': 18, 'name': 'Drama'}]      NaN
# 2       0.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
# 3  100000.0                                                 []      NaN
# 4       0.0  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...      NaN
# 5       0.0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...      NaN
#
#          id original_language                     original_title  \
# 1  268253.0                pl  Życie za życie. Maksymilian Kolbe
# 2   63163.0                ru                 Мастер и Маргарита
# 3   30356.0                en      Whispers from a Shallow Grave
# 4  218584.0                pt       Viúva Rica Solteira Não Fica
# 5   58520.0                en           Live Freaky! Die Freaky!
#
#                                             overview  popularity  \
# 1  The story of catholic saint Maximilian Kolbe (...       2.794
# 2  Master is a talented writer in Moscow working ...       3.396
# 3  When a beautiful photo model disappears, polic...       1.662
# 4  Ana Catarina returns from Brazil with her fath...       1.148
# 5  In a distant future, a cult forms around the M...       1.451
#
#                         poster_path  \
# 1  /40k326IEGBbAtt81yRR8HlmWSSL.jpg
# 2  /hvtnknTQBCKpDTXN2zqM5Nem5VE.jpg
# 3  /cjRqAh3u2Z0MBx9GtT1k7Z9732w.jpg
# 4  /nnwjvQI9TYhpVFWTrjF2tQd2Zql.jpg
# 5  /eL3XPWneGaYWDwdKgJXE3nfOVkG.jpg
#
#                                 production_companies  \
# 1  [{'id': 73037, 'logo_path': None, 'name': 'Stu...
# 2  [{'id': 22085, 'logo_path': None, 'name': 'Tvo...
# 3                                                 []
# 4  [{'id': 3289, 'logo_path': None, 'name': 'Clap...
# 5                                                 []
#
#                                 production_countries release_date  revenue  \
# 1  [{'iso_3166_1': 'PL', 'name': 'Poland'}, {'iso...   1991-04-01      0.0
# 2           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1994-06-06      0.0
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   1997-01-01      0.0
# 4  [{'iso_3166_1': 'BR', 'name': 'Brazil'}, {'iso...   2006-11-16  56360.0
# 5  [{'iso_3166_1': 'US', 'name': 'United States o...   2006-01-31      0.0
#
#    runtime                                   spoken_languages    status  \
# 1     90.0  [{'english_name': 'Italian', 'iso_639_1': 'it'...  Released
# 2    128.0  [{'english_name': 'Russian', 'iso_639_1': 'ru'...  Released
# 3     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4    135.0  [{'english_name': 'Portuguese', 'iso_639_1': '...  Released
# 5     75.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                   tagline                            title  video  \
# 1                     NaN  Life for Life: Maximilian Kolbe    0.0
# 2  Manuscripts don't burn         The Master and Margarita    0.0
# 3                     NaN    Whispers from a Shallow Grave    0.0
# 4                     NaN     Viúva Rica Solteira Não Fica    0.0
# 5                     NaN         Live Freaky! Die Freaky!    0.0
#
#    vote_average  vote_count certification
# 1         6.133        16.0           NaN
# 2         5.848        23.0           NaN
# 3         2.000         2.0           NaN
# 4         7.200         6.0           NaN
# 5         3.800         8.0            NR

# %%
# def get_schema(table,debug=False):
#     ## save pandas dtypes in list, make empty dict
#     dtypes = table.dtypes
#     schema = {}
    
#     # for each column
#     for col in dtypes.index:
#         ## print info if in debug mode
#         if debug:
#             print(f"{col} = {dtypes.loc[col]}")

#         ## if its a string column (object)
#         if dtypes.loc[col]=='object':
            
#             ## Fill null values and make sure whole column is str
#             data = table[col].fillna('').astype(str)
            
#             ## get len first
#             len_str = data.map(len).max()
            
#             ## if the string is shorter than 21845 use String
#             # (forget how i knew it was max size)
#             if len_str < 21845:
#                 schema[col] = String( len_str + 1)
                
#             ## If longer use Text
#             else:
#                 schema[col] = Text(len_str+1)
        
#         # if float make Float
#         elif dtypes.loc[col] == 'float':
#             schema[col] = Float()

#         ## if int make Integer
#         elif dtypes.loc[col] == 'int':
#             schema[col] = Integer()
            
#         ## if bool make Boolean
#         elif dtypes.loc[col] == 'bool':
#             schema[col] = Boolean()
            
#     return schema

# %% [markdown]
# # Final Tables Check

# %%
## Test your connection by checking for any tables that exist (there should be none at this point)
q = """SHOW TABLES;"""
pd.read_sql(q, engine)
# Out:
#   Tables_in_movies
# 0           genres
# 1     title_basics
# 2      title_genre
# 3     title_genres
# 4    title_ratings
# 5        tmdb_data
# 6    tmdb_data_aab
# 7    tmdb_data_mvp
