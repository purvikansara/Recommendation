# %% [markdown]
# Imports and Downloading Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
## Making "Data" Folder to save IMDB files
os.makedirs("Data/",exist_ok=True)
os.listdir("Data/")
# Out:
# ['title_basics_cleaned.csv.gz',
#  'title_ratings_cleaned.csv.gz',
#  'tmdb_api_results_2000.json',
#  'final_tmdb_data_2000.csv.gz',
#  'tmdb_api_results_2001.json',
#  'final_tmdb_data_2001.csv.gz',
#  'title_akas_cleaned.csv.gz']

# %%
## title basics 
url_title_basics = 'https://datasets.imdbws.com/title.basics.tsv.gz'
basics = pd.read_csv(url_title_basics, sep='\t',low_memory=True)
basics
# Out:
# /var/folders/td/cybzgn316hq8r5cn05lb0y2m0000gn/T/ipykernel_41557/4227646055.py:3: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   basics = pd.read_csv(url_title_basics, sep='\t',low_memory=True)
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 9455644  tt9916848  tvEpisode              Episode #3.17
# 9455645  tt9916850  tvEpisode              Episode #3.19
# 9455646  tt9916852  tvEpisode              Episode #3.20
# 9455647  tt9916856      short                   The Wind
# 9455648  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894      \N              1
# 1           Le clown et ses chiens       0      1892      \N              5
# 2                   Pauvre Pierrot       0      1892      \N              4
# 3                      Un bon bock       0      1892      \N             12
# 4                 Blacksmith Scene       0      1893      \N              1
# ...                            ...     ...       ...     ...            ...
# 9455644              Episode #3.17       0      2010      \N             \N
# 9455645              Episode #3.19       0      2010      \N             \N
# 9455646              Episode #3.20       0      2010      \N             \N
# 9455647                   The Wind       0      2015      \N             27
# 9455648  Horrid Henry Knows It All       0      2014      \N             10
#
#                              genres
# 0                 Documentary,Short
# 1                   Animation,Short
# 2          Animation,Comedy,Romance
# 3                   Animation,Short
# 4                      Comedy,Short
# ...                             ...
# 9455644         Action,Drama,Family
# 9455645         Action,Drama,Family
# 9455646         Action,Drama,Family
# 9455647                       Short
# 9455648  Adventure,Animation,Comedy
#
# [9455649 rows x 9 columns]

# %%
basics.replace({'\\N':np.nan},inplace=True)

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9455649 entries, 0 to 9455648
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 649.3+ MB

# %%
## title ratings
url_title_ratings ="https://datasets.imdbws.com/title.ratings.tsv.gz"
ratings = pd.read_csv(url_title_ratings,sep='\t',low_memory=True)
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1928
# 1        tt0000002            5.8       261
# 2        tt0000003            6.5      1744
# 3        tt0000004            5.6       176
# 4        tt0000005            6.2      2556
# ...            ...            ...       ...
# 1258351  tt9916690            7.4         6
# 1258352  tt9916720            5.4       287
# 1258353  tt9916730            8.0         8
# 1258354  tt9916766            6.7        21
# 1258355  tt9916778            7.3        35
#
# [1258356 rows x 3 columns]

# %%
## title AKAs
url_title_akas ="https://datasets.imdbws.com/title.akas.tsv.gz"
akas = pd.read_csv(url_title_akas,sep='\t',low_memory=True)
akas
# Out:
# /var/folders/td/cybzgn316hq8r5cn05lb0y2m0000gn/T/ipykernel_41557/1170270994.py:3: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   akas = pd.read_csv(url_title_akas,sep='\t',low_memory=True)
#             titleId  ordering                      title region language  \
# 0         tt0000001         1                 Карменсіта     UA       \N
# 1         tt0000001         2                 Carmencita     DE       \N
# 2         tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3         tt0000001         4                 Καρμενσίτα     GR       \N
# 4         tt0000001         5                 Карменсита     RU       \N
# ...             ...       ...                        ...    ...      ...
# 34227293  tt9916852         5             Episódio #3.20     PT       pt
# 34227294  tt9916852         6             Episodio #3.20     IT       it
# 34227295  tt9916852         7               एपिसोड #3.20     IN       hi
# 34227296  tt9916856         1                   The Wind     DE       \N
# 34227297  tt9916856         2                   The Wind     \N       \N
#
#                 types     attributes isOriginalTitle
# 0         imdbDisplay             \N               0
# 1                  \N  literal title               0
# 2         imdbDisplay             \N               0
# 3         imdbDisplay             \N               0
# 4         imdbDisplay             \N               0
# ...               ...            ...             ...
# 34227293           \N             \N               0
# 34227294           \N             \N               0
# 34227295           \N             \N               0
# 34227296  imdbDisplay             \N               0
# 34227297     original             \N               1
#
# [34227298 rows x 8 columns]

# %%
## check nulls
basics.isna().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle           11
# originalTitle          11
# isAdult                 1
# startYear         1266376
# endYear           9355644
# runtimeMinutes    6752370
# genres             431724
# dtype: int64

# %%
## Replace "\N" with np.nan
basics.replace({'\\N':np.nan},inplace=True)
basics.isna().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle           11
# originalTitle          11
# isAdult                 1
# startYear         1266376
# endYear           9355644
# runtimeMinutes    6752370
# genres             431724
# dtype: int64

# %%
# Replace "\N" with np.nan (if any)
ratings.replace({'\\N':np.nan},inplace=True)
ratings.isna().sum()
# Out:
# tconst           0
# averageRating    0
# numVotes         0
# dtype: int64

# %%
# Replace "\N" with np.nan (if any)
akas.replace({'\\N':np.nan},inplace=True)
akas.isna().sum()
# Out:
# titleId                   0
# ordering                  0
# title                     5
# region              1872941
# language            6431023
# types              28809481
# attributes         33975793
# isOriginalTitle        2109
# dtype: int64

# %%
## Eliminate movies that are null for runtimeMinute, genres
basics = basics.dropna(subset=['runtimeMinutes','genres'])
basics.isna().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle            1
# originalTitle           1
# isAdult                 0
# startYear          116899
# endYear           2581232
# runtimeMinutes          0
# genres                  0
# dtype: int64

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2628341 entries, 0 to 9455648
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 200.5+ MB

# %%
## keep only titleType==Movie
basics = basics.loc[ basics['titleType']=='movie']
basics
# Out:
#             tconst titleType  \
# 8        tt0000009     movie
# 144      tt0000147     movie
# 570      tt0000574     movie
# 587      tt0000591     movie
# 672      tt0000679     movie
# ...            ...       ...
# 9455414  tt9916362     movie
# 9455498  tt9916538     movie
# 9455539  tt9916622     movie
# 9455566  tt9916680     movie
# 9455599  tt9916754     movie
#
#                                               primaryTitle  \
# 8                                               Miss Jerry
# 144                          The Corbett-Fitzsimmons Fight
# 570                            The Story of the Kelly Gang
# 587                                       The Prodigal Son
# 672                         The Fairylogue and Radio-Plays
# ...                                                    ...
# 9455414                                              Coven
# 9455498                                Kuambil Lagi Hatiku
# 9455539        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9455566  De la ilusión al desconcierto: cine colombiano...
# 9455599                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult startYear  \
# 8                                               Miss Jerry       0      1894
# 144                          The Corbett-Fitzsimmons Fight       0      1897
# 570                            The Story of the Kelly Gang       0      1906
# 587                                      L'enfant prodigue       0      1907
# 672                         The Fairylogue and Radio-Plays       0      1908
# ...                                                    ...     ...       ...
# 9455414                                           Akelarre       0      2020
# 9455498                                Kuambil Lagi Hatiku       0      2019
# 9455539        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 9455566  De la ilusión al desconcierto: cine colombiano...       0      2007
# 9455599                     Chico Albuquerque - Revelações       0      2013
#
#         endYear runtimeMinutes                      genres
# 8           NaN             45                     Romance
# 144         NaN            100      Documentary,News,Sport
# 570         NaN             70  Action,Adventure,Biography
# 587         NaN             90                       Drama
# 672         NaN            120           Adventure,Fantasy
# ...         ...            ...                         ...
# 9455414     NaN             92               Drama,History
# 9455498     NaN            123                       Drama
# 9455539     NaN             57                 Documentary
# 9455566     NaN            100                 Documentary
# 9455599     NaN             49                 Documentary
#
# [373848 rows x 9 columns]

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 373848 entries, 8 to 9455599
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          373848 non-null  object
#  1   titleType       373848 non-null  object
#  2   primaryTitle    373848 non-null  object
#  3   originalTitle   373848 non-null  object
#  4   isAdult         373848 non-null  object
#  5   startYear       367849 non-null  object
#  6   endYear         0 non-null       object
#  7   runtimeMinutes  373848 non-null  object
#  8   genres          373848 non-null  object
# dtypes: object(9)
# memory usage: 28.5+ MB

# %%
### Convert startyear to numeric for slicing
## convert numeric features
basics['startYear'] = basics['startYear'].astype(float)

# %%
## keep startYear 2000-2022
basics = basics[(basics['startYear']>=2000)&(basics['startYear']<2022)]
basics
# Out:
#             tconst titleType  \
# 13082    tt0013274     movie
# 34804    tt0035423     movie
# 61117    tt0062336     movie
# 66337    tt0067683     movie
# 67670    tt0069049     movie
# ...            ...       ...
# 9455414  tt9916362     movie
# 9455498  tt9916538     movie
# 9455539  tt9916622     movie
# 9455566  tt9916680     movie
# 9455599  tt9916754     movie
#
#                                               primaryTitle  \
# 13082                          Istoriya grazhdanskoy voyny
# 34804                                       Kate & Leopold
# 61117    The Tango of the Widower and Its Distorting Mi...
# 66337             Workers '71: Nothing About Us Without Us
# 67670                           The Other Side of the Wind
# ...                                                    ...
# 9455414                                              Coven
# 9455498                                Kuambil Lagi Hatiku
# 9455539        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9455566  De la ilusión al desconcierto: cine colombiano...
# 9455599                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult  startYear  \
# 13082                          Istoriya grazhdanskoy voyny       0     2021.0
# 34804                                       Kate & Leopold       0     2001.0
# 61117            El Tango del Viudo y Su Espejo Deformante       0     2020.0
# 66337                   Robotnicy 1971 - Nic o nas bez nas       0     2006.0
# 67670                           The Other Side of the Wind       0     2018.0
# ...                                                    ...     ...        ...
# 9455414                                           Akelarre       0     2020.0
# 9455498                                Kuambil Lagi Hatiku       0     2019.0
# 9455539        Rodolpho Teóphilo - O Legado de um Pioneiro       0     2015.0
# 9455566  De la ilusión al desconcierto: cine colombiano...       0     2007.0
# 9455599                     Chico Albuquerque - Revelações       0     2013.0
#
#         endYear runtimeMinutes                  genres
# 13082       NaN            133             Documentary
# 34804       NaN            118  Comedy,Fantasy,Romance
# 61117       NaN             70                   Drama
# 66337       NaN             47             Documentary
# 67670       NaN            122                   Drama
# ...         ...            ...                     ...
# 9455414     NaN             92           Drama,History
# 9455498     NaN            123                   Drama
# 9455539     NaN             57             Documentary
# 9455566     NaN            100             Documentary
# 9455599     NaN             49             Documentary
#
# [208658 rows x 9 columns]

# %%
## Eliminate movies that include  "Documentary" in genre 
is_documentary = basics['genres'].str.contains('documentary',case=False)
basics = basics[~is_documentary]
basics.head()
# Out:
#           tconst titleType                                       primaryTitle  \
# 34804  tt0035423     movie                                     Kate & Leopold
# 61117  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 67670  tt0069049     movie                         The Other Side of the Wind
# 77965  tt0079644     movie                                      November 1828
# 86802  tt0088751     movie                                  The Naked Monster
#
#                                    originalTitle isAdult  startYear endYear  \
# 34804                             Kate & Leopold       0     2001.0     NaN
# 61117  El Tango del Viudo y Su Espejo Deformante       0     2020.0     NaN
# 67670                 The Other Side of the Wind       0     2018.0     NaN
# 77965                              November 1828       0     2001.0     NaN
# 86802                          The Naked Monster       0     2005.0     NaN
#
#       runtimeMinutes                  genres
# 34804            118  Comedy,Fantasy,Romance
# 61117             70                   Drama
# 67670            122                   Drama
# 77965            140               Drama,War
# 86802            100    Comedy,Horror,Sci-Fi

# %%
#Removing Non-US From Title Basics
keepers = basics['tconst'].isin(akas['titleId'])
basics = basics[keepers]
basics
# Out:
#             tconst titleType  \
# 34804    tt0035423     movie
# 61117    tt0062336     movie
# 67670    tt0069049     movie
# 77965    tt0079644     movie
# 86802    tt0088751     movie
# ...            ...       ...
# 9455321  tt9916170     movie
# 9455330  tt9916190     movie
# 9455369  tt9916270     movie
# 9455414  tt9916362     movie
# 9455498  tt9916538     movie
#
#                                               primaryTitle  \
# 34804                                       Kate & Leopold
# 61117    The Tango of the Widower and Its Distorting Mi...
# 67670                           The Other Side of the Wind
# 77965                                        November 1828
# 86802                                    The Naked Monster
# ...                                                    ...
# 9455321                                      The Rehearsal
# 9455330                                          Safeguard
# 9455369                           Il talento del calabrone
# 9455414                                              Coven
# 9455498                                Kuambil Lagi Hatiku
#
#                                      originalTitle isAdult  startYear endYear  \
# 34804                               Kate & Leopold       0     2001.0     NaN
# 61117    El Tango del Viudo y Su Espejo Deformante       0     2020.0     NaN
# 67670                   The Other Side of the Wind       0     2018.0     NaN
# 77965                                November 1828       0     2001.0     NaN
# 86802                            The Naked Monster       0     2005.0     NaN
# ...                                            ...     ...        ...     ...
# 9455321                                   O Ensaio       0     2019.0     NaN
# 9455330                                  Safeguard       0     2020.0     NaN
# 9455369                   Il talento del calabrone       0     2020.0     NaN
# 9455414                                   Akelarre       0     2020.0     NaN
# 9455498                        Kuambil Lagi Hatiku       0     2019.0     NaN
#
#         runtimeMinutes                     genres
# 34804              118     Comedy,Fantasy,Romance
# 61117               70                      Drama
# 67670              122                      Drama
# 77965              140                  Drama,War
# 86802              100       Comedy,Horror,Sci-Fi
# ...                ...                        ...
# 9455321             51                      Drama
# 9455330             95  Action,Adventure,Thriller
# 9455369             84                   Thriller
# 9455414             92              Drama,History
# 9455498            123                      Drama
#
# [136812 rows x 9 columns]

# %%
## The AKAs file has the information on country where it released and language
akas = akas[(akas['region'] == 'US')]
akas
# Out:
#             titleId  ordering                          title region language  \
# 5         tt0000001         6                     Carmencita     US      NaN
# 14        tt0000002         7         The Clown and His Dogs     US      NaN
# 33        tt0000005        10               Blacksmith Scene     US      NaN
# 36        tt0000005         1            Blacksmithing Scene     US      NaN
# 41        tt0000005         6            Blacksmith Scene #1     US      NaN
# ...             ...       ...                            ...    ...      ...
# 34226969  tt9916702         1  Loving London: The Playground     US      NaN
# 34227006  tt9916720        10                The Demonic Nun     US      NaN
# 34227008  tt9916720        12                      The Nun 2     US      NaN
# 34227026  tt9916756         1       Pretty Pretty Black Girl     US      NaN
# 34227042  tt9916764         1                             38     US      NaN
#
#                 types             attributes isOriginalTitle
# 5         imdbDisplay                    NaN               0
# 14                NaN  literal English title               0
# 33        imdbDisplay                    NaN               0
# 36        alternative                    NaN               0
# 41        alternative                    NaN               0
# ...               ...                    ...             ...
# 34226969          NaN                    NaN               0
# 34227006           tv                    NaN               0
# 34227008  imdbDisplay                    NaN               0
# 34227026  imdbDisplay                    NaN               0
# 34227042  imdbDisplay                    NaN               0
#
# [1394680 rows x 8 columns]

# %%
keepers = ratings['tconst'].isin(akas['titleId'])
ratings = ratings[keepers]
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1928
# 1        tt0000002            5.8       261
# 4        tt0000005            6.2      2556
# 5        tt0000006            5.1       175
# 6        tt0000007            5.4       797
# ...            ...            ...       ...
# 1258330  tt9916204            8.2       251
# 1258336  tt9916348            8.5        17
# 1258337  tt9916362            6.4      5062
# 1258341  tt9916428            3.8        14
# 1258352  tt9916720            5.4       287
#
# [479153 rows x 3 columns]

# %% [markdown]
# Saving Final Files

# %%
## Saving and immediately loading (to verify)
basics.to_csv('Data/title_basics_cleaned.csv.gz',compression='gzip',index=False)
basics = pd.read_csv('Data/title_basics_cleaned.csv.gz')
basics.info()
basics.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136812 entries, 0 to 136811
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          136812 non-null  object
#  1   titleType       136812 non-null  object
#  2   primaryTitle    136812 non-null  object
#  3   originalTitle   136812 non-null  object
#  4   isAdult         136812 non-null  int64
#  5   startYear       136812 non-null  float64
#  6   endYear         0 non-null       float64
#  7   runtimeMinutes  136812 non-null  int64
#  8   genres          136812 non-null  object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 9.4+ MB
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0079644     movie                                      November 1828
# 4  tt0088751     movie                                  The Naked Monster
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0     2020.0      NaN
# 2                 The Other Side of the Wind        0     2018.0      NaN
# 3                              November 1828        0     2001.0      NaN
# 4                          The Naked Monster        0     2005.0      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             140               Drama,War
# 4             100    Comedy,Horror,Sci-Fi

# %%
ratings.to_csv('Data/title_ratings_cleaned.csv.gz',compression='gzip',index=False)
ratings = pd.read_csv('Data/title_ratings_cleaned.csv.gz')
ratings.info()
ratings.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479153 entries, 0 to 479152
# Data columns (total 3 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tconst         479153 non-null  object
#  1   averageRating  479153 non-null  float64
#  2   numVotes       479153 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 11.0+ MB
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1928
# 1  tt0000002            5.8       261
# 2  tt0000005            6.2      2556
# 3  tt0000006            5.1       175
# 4  tt0000007            5.4       797

# %%
akas.to_csv('Data/title_akas_cleaned.csv.gz',compression='gzip',index=False)
akas = pd.read_csv('Data/title_akas_cleaned.csv.gz')
akas.info()
akas.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1394680 entries, 0 to 1394679
# Data columns (total 8 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   titleId          1394680 non-null  object
#  1   ordering         1394680 non-null  int64
#  2   title            1394680 non-null  object
#  3   region           1394680 non-null  object
#  4   language         3744 non-null     object
#  5   types            967716 non-null   object
#  6   attributes       45543 non-null    object
#  7   isOriginalTitle  1393335 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 85.1+ MB
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 2  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#               attributes  isOriginalTitle
# 0                    NaN              0.0
# 1  literal English title              0.0
# 2                    NaN              0.0
# 3                    NaN              0.0
# 4                    NaN              0.0

# %%
# optional 
os.listdir("Data/")
# Out:
# ['title_basics_cleaned.csv.gz',
#  'title_ratings_cleaned.csv.gz',
#  'tmdb_api_results_2000.json',
#  'final_tmdb_data_2000.csv.gz',
#  'tmdb_api_results_2001.json',
#  'final_tmdb_data_2001.csv.gz',
#  'title_akas_cleaned.csv.gz']
