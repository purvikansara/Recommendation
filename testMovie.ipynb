# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
## Making "Data" Folder to save IMDB files
os.makedirs("Data/",exist_ok=True)
os.listdir("Data/")
# Out:
# ['title_basics_cleaned.csv.gz',
#  'title_ratings_cleaned.csv.gz',
#  'tmdb_api_results_2000.json',
#  'final_tmdb_data_2000.csv.gz',
#  'tmdb_api_results_2001.json',
#  'final_tmdb_data_2001.csv.gz',
#  'title_akas_cleaned.csv.gz']

# %%
## title basics 
url_title_basics = 'https://datasets.imdbws.com/title.basics.tsv.gz'
basics = pd.read_csv(url_title_basics, sep='\t',low_memory=True)
basics
# Out:
# /var/folders/td/cybzgn316hq8r5cn05lb0y2m0000gn/T/ipykernel_1122/4227646055.py:3: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   basics = pd.read_csv(url_title_basics, sep='\t',low_memory=True)
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 9248445  tt9916848  tvEpisode              Episode #3.17
# 9248446  tt9916850  tvEpisode              Episode #3.19
# 9248447  tt9916852  tvEpisode              Episode #3.20
# 9248448  tt9916856      short                   The Wind
# 9248449  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894      \N              1
# 1           Le clown et ses chiens       0      1892      \N              5
# 2                   Pauvre Pierrot       0      1892      \N              4
# 3                      Un bon bock       0      1892      \N             12
# 4                 Blacksmith Scene       0      1893      \N              1
# ...                            ...     ...       ...     ...            ...
# 9248445              Episode #3.17       0      2010      \N             \N
# 9248446              Episode #3.19       0      2010      \N             \N
# 9248447              Episode #3.20       0      2010      \N             \N
# 9248448                   The Wind       0      2015      \N             27
# 9248449  Horrid Henry Knows It All       0      2014      \N             10
#
#                              genres
# 0                 Documentary,Short
# 1                   Animation,Short
# 2          Animation,Comedy,Romance
# 3                   Animation,Short
# 4                      Comedy,Short
# ...                             ...
# 9248445         Action,Drama,Family
# 9248446         Action,Drama,Family
# 9248447         Action,Drama,Family
# 9248448                       Short
# 9248449  Adventure,Animation,Comedy
#
# [9248450 rows x 9 columns]

# %%
## title ratings
url_title_ratings ="https://datasets.imdbws.com/title.ratings.tsv.gz"
ratings = pd.read_csv(url_title_ratings,sep='\t',low_memory=True)
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1910
# 1        tt0000002            5.8       257
# 2        tt0000003            6.5      1715
# 3        tt0000004            5.6       169
# 4        tt0000005            6.2      2530
# ...            ...            ...       ...
# 1261712  tt9916690            6.5         6
# 1261713  tt9916720            5.2       258
# 1261714  tt9916730            8.4         6
# 1261715  tt9916766            6.8        21
# 1261716  tt9916778            7.2        35
#
# [1261717 rows x 3 columns]

# %%
## title AKAs
url_title_akas ="https://datasets.imdbws.com/title.akas.tsv.gz"
akas = pd.read_csv(url_title_akas,sep='\t',low_memory=True)
akas
# Out:
# /var/folders/td/cybzgn316hq8r5cn05lb0y2m0000gn/T/ipykernel_1122/1170270994.py:3: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   akas = pd.read_csv(url_title_akas,sep='\t',low_memory=True)
#             titleId  ordering                      title region language  \
# 0         tt0000001         1                 Карменсіта     UA       \N
# 1         tt0000001         2                 Carmencita     DE       \N
# 2         tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3         tt0000001         4                 Καρμενσίτα     GR       \N
# 4         tt0000001         5                 Карменсита     RU       \N
# ...             ...       ...                        ...    ...      ...
# 33280938  tt9916852         5             Episódio #3.20     PT       pt
# 33280939  tt9916852         6             Episodio #3.20     IT       it
# 33280940  tt9916852         7               एपिसोड #3.20     IN       hi
# 33280941  tt9916856         1                   The Wind     DE       \N
# 33280942  tt9916856         2                   The Wind     \N       \N
#
#                 types     attributes isOriginalTitle
# 0         imdbDisplay             \N               0
# 1                  \N  literal title               0
# 2         imdbDisplay             \N               0
# 3         imdbDisplay             \N               0
# 4         imdbDisplay             \N               0
# ...               ...            ...             ...
# 33280938           \N             \N               0
# 33280939           \N             \N               0
# 33280940           \N             \N               0
# 33280941  imdbDisplay             \N               0
# 33280942     original             \N               1
#
# [33280943 rows x 8 columns]

# %%
## check nulls
basics.isna().sum()
# Out:
# tconst             0
# titleType          0
# primaryTitle      11
# originalTitle     11
# isAdult            0
# startYear          0
# endYear            0
# runtimeMinutes     0
# genres            10
# dtype: int64

# %%
## Replace "\N" with np.nan
basics.replace({'\\N':np.nan},inplace=True)
basics.isna().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle           11
# originalTitle          11
# isAdult                 1
# startYear         1233296
# endYear           9151992
# runtimeMinutes    6771090
# genres             427797
# dtype: int64

# %%
# Replace "\N" with np.nan (if any)
ratings.replace({'\\N':np.nan},inplace=True)
ratings.isna().sum()
# Out:
# tconst           0
# averageRating    0
# numVotes         0
# dtype: int64

# %%
# Replace "\N" with np.nan (if any)
akas.replace({'\\N':np.nan},inplace=True)
akas.isna().sum()
# Out:
# titleId                   0
# ordering                  0
# title                     5
# region              1863183
# language            6270153
# types              27986080
# attributes         33033661
# isOriginalTitle        2187
# dtype: int64

# %%
## Eliminate movies that are null for runtimeMinute, genres
basics = basics.dropna(subset=['runtimeMinutes','genres'])
basics.isna().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle            1
# originalTitle           1
# isAdult                 0
# startYear           36428
# endYear           2364385
# runtimeMinutes          0
# genres                  0
# dtype: int64

# %%
## keep only titleType==Movie
basics = basics.loc[ basics['titleType']=='movie']
basics
# Out:
#             tconst titleType  \
# 8        tt0000009     movie
# 570      tt0000574     movie
# 587      tt0000591     movie
# 672      tt0000679     movie
# 1172     tt0001184     movie
# ...            ...       ...
# 9248215  tt9916362     movie
# 9248299  tt9916538     movie
# 9248340  tt9916622     movie
# 9248367  tt9916680     movie
# 9248400  tt9916754     movie
#
#                                               primaryTitle  \
# 8                                               Miss Jerry
# 570                            The Story of the Kelly Gang
# 587                                       The Prodigal Son
# 672                         The Fairylogue and Radio-Plays
# 1172                               Don Juan de Serrallonga
# ...                                                    ...
# 9248215                                              Coven
# 9248299                                Kuambil Lagi Hatiku
# 9248340        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9248367  De la ilusión al desconcierto: cine colombiano...
# 9248400                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult startYear  \
# 8                                               Miss Jerry       0      1894
# 570                            The Story of the Kelly Gang       0      1906
# 587                                      L'enfant prodigue       0      1907
# 672                         The Fairylogue and Radio-Plays       0      1908
# 1172                               Don Juan de Serrallonga       0      1910
# ...                                                    ...     ...       ...
# 9248215                                           Akelarre       0      2020
# 9248299                                Kuambil Lagi Hatiku       0      2019
# 9248340        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 9248367  De la ilusión al desconcierto: cine colombiano...       0      2007
# 9248400                     Chico Albuquerque - Revelações       0      2013
#
#         endYear runtimeMinutes                      genres
# 8           NaN             45                     Romance
# 570         NaN             70  Action,Adventure,Biography
# 587         NaN             90                       Drama
# 672         NaN            120           Adventure,Fantasy
# 1172        NaN             58             Adventure,Drama
# ...         ...            ...                         ...
# 9248215     NaN             92               Drama,History
# 9248299     NaN            123                       Drama
# 9248340     NaN             57                 Documentary
# 9248367     NaN            100                 Documentary
# 9248400     NaN             49                 Documentary
#
# [368540 rows x 9 columns]

# %%
### Convert startyear to numeric for slicing
## convert numeric features
basics['startYear'] = basics['startYear'].astype(float)

# %%
## keep startYear 2000-2022
basics = basics[(basics['startYear']>=2000)&(basics['startYear']<2022)]
basics
# Out:
#             tconst titleType  \
# 13079    tt0013274     movie
# 34792    tt0035423     movie
# 61094    tt0062336     movie
# 66309    tt0067683     movie
# 67640    tt0069049     movie
# ...            ...       ...
# 9248215  tt9916362     movie
# 9248299  tt9916538     movie
# 9248340  tt9916622     movie
# 9248367  tt9916680     movie
# 9248400  tt9916754     movie
#
#                                               primaryTitle  \
# 13079                          Istoriya grazhdanskoy voyny
# 34792                                       Kate & Leopold
# 61094    The Tango of the Widower and Its Distorting Mi...
# 66309             Workers '71: Nothing About Us Without Us
# 67640                           The Other Side of the Wind
# ...                                                    ...
# 9248215                                              Coven
# 9248299                                Kuambil Lagi Hatiku
# 9248340        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9248367  De la ilusión al desconcierto: cine colombiano...
# 9248400                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult  startYear  \
# 13079                          Istoriya grazhdanskoy voyny       0     2021.0
# 34792                                       Kate & Leopold       0     2001.0
# 61094            El Tango del Viudo y Su Espejo Deformante       0     2020.0
# 66309                   Robotnicy 1971 - Nic o nas bez nas       0     2006.0
# 67640                           The Other Side of the Wind       0     2018.0
# ...                                                    ...     ...        ...
# 9248215                                           Akelarre       0     2020.0
# 9248299                                Kuambil Lagi Hatiku       0     2019.0
# 9248340        Rodolpho Teóphilo - O Legado de um Pioneiro       0     2015.0
# 9248367  De la ilusión al desconcierto: cine colombiano...       0     2007.0
# 9248400                     Chico Albuquerque - Revelações       0     2013.0
#
#         endYear runtimeMinutes                  genres
# 13079       NaN            133             Documentary
# 34792       NaN            118  Comedy,Fantasy,Romance
# 61094       NaN             70                   Drama
# 66309       NaN             47             Documentary
# 67640       NaN            122                   Drama
# ...         ...            ...                     ...
# 9248215     NaN             92           Drama,History
# 9248299     NaN            123                   Drama
# 9248340     NaN             57             Documentary
# 9248367     NaN            100             Documentary
# 9248400     NaN             49             Documentary
#
# [207677 rows x 9 columns]

# %%
## Eliminate movies that include  "Documentary" in genre 
is_documentary = basics['genres'].str.contains('documentary',case=False)
basics = basics[~is_documentary]
basics.head()
# Out:
#           tconst titleType                                       primaryTitle  \
# 34792  tt0035423     movie                                     Kate & Leopold
# 61094  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 67640  tt0069049     movie                         The Other Side of the Wind
# 77934  tt0079644     movie                                      November 1828
# 86771  tt0088751     movie                                  The Naked Monster
#
#                                    originalTitle isAdult  startYear endYear  \
# 34792                             Kate & Leopold       0     2001.0     NaN
# 61094  El Tango del Viudo y Su Espejo Deformante       0     2020.0     NaN
# 67640                 The Other Side of the Wind       0     2018.0     NaN
# 77934                              November 1828       0     2001.0     NaN
# 86771                          The Naked Monster       0     2005.0     NaN
#
#       runtimeMinutes                  genres
# 34792            118  Comedy,Fantasy,Romance
# 61094             70                   Drama
# 67640            122                   Drama
# 77934            140               Drama,War
# 86771            100    Comedy,Horror,Sci-Fi

# %%
## The AKAs file has the information on country where it released and language
akas = akas[(akas['region'] == 'US')]
akas
# Out:
#             titleId  ordering                          title region language  \
# 5         tt0000001         6                     Carmencita     US      NaN
# 14        tt0000002         7         The Clown and His Dogs     US      NaN
# 33        tt0000005        10               Blacksmith Scene     US      NaN
# 36        tt0000005         1            Blacksmithing Scene     US      NaN
# 41        tt0000005         6            Blacksmith Scene #1     US      NaN
# ...             ...       ...                            ...    ...      ...
# 33280615  tt9916702         1  Loving London: The Playground     US      NaN
# 33280652  tt9916720        10                The Demonic Nun     US      NaN
# 33280654  tt9916720        12                      The Nun 2     US      NaN
# 33280671  tt9916756         1       Pretty Pretty Black Girl     US      NaN
# 33280687  tt9916764         1                             38     US      NaN
#
#                 types             attributes isOriginalTitle
# 5         imdbDisplay                    NaN               0
# 14                NaN  literal English title               0
# 33        imdbDisplay                    NaN               0
# 36        alternative                    NaN               0
# 41        alternative                    NaN               0
# ...               ...                    ...             ...
# 33280615          NaN                    NaN               0
# 33280652           tv                    NaN               0
# 33280654  imdbDisplay                    NaN               0
# 33280671  imdbDisplay                    NaN               0
# 33280687  imdbDisplay                    NaN               0
#
# [1353273 rows x 8 columns]

# %%
#Removing Non-US From Title Basics
keepers = basics['tconst'].isin(akas['titleId'])
basics = basics[keepers]
basics
# Out:
#             tconst titleType  \
# 34792    tt0035423     movie
# 61094    tt0062336     movie
# 67640    tt0069049     movie
# 86771    tt0088751     movie
# 93907    tt0096056     movie
# ...            ...       ...
# 9247586  tt9914942     movie
# 9247982  tt9915872     movie
# 9248122  tt9916170     movie
# 9248131  tt9916190     movie
# 9248215  tt9916362     movie
#
#                                               primaryTitle  \
# 34792                                       Kate & Leopold
# 61094    The Tango of the Widower and Its Distorting Mi...
# 67640                           The Other Side of the Wind
# 86771                                    The Naked Monster
# 93907                                 Crime and Punishment
# ...                                                    ...
# 9247586                             Life Without Sara Amat
# 9247982                               The Last White Witch
# 9248122                                      The Rehearsal
# 9248131                                          Safeguard
# 9248215                                              Coven
#
#                                      originalTitle isAdult  startYear endYear  \
# 34792                               Kate & Leopold       0     2001.0     NaN
# 61094    El Tango del Viudo y Su Espejo Deformante       0     2020.0     NaN
# 67640                   The Other Side of the Wind       0     2018.0     NaN
# 86771                            The Naked Monster       0     2005.0     NaN
# 93907                         Crime and Punishment       0     2002.0     NaN
# ...                                            ...     ...        ...     ...
# 9247586                 La vida sense la Sara Amat       0     2019.0     NaN
# 9247982                  My Girlfriend is a Wizard       0     2019.0     NaN
# 9248122                                   O Ensaio       0     2019.0     NaN
# 9248131                                  Safeguard       0     2020.0     NaN
# 9248215                                   Akelarre       0     2020.0     NaN
#
#         runtimeMinutes                     genres
# 34792              118     Comedy,Fantasy,Romance
# 61094               70                      Drama
# 67640              122                      Drama
# 86771              100       Comedy,Horror,Sci-Fi
# 93907              126                      Drama
# ...                ...                        ...
# 9247586             74                      Drama
# 9247982             97       Comedy,Drama,Fantasy
# 9248122             51                      Drama
# 9248131             95  Action,Adventure,Thriller
# 9248215             92              Drama,History
#
# [79671 rows x 9 columns]

# %%
keepers = ratings['tconst'].isin(akas['titleId'])
ratings = ratings[keepers]
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1910
# 1        tt0000002            5.8       257
# 4        tt0000005            6.2      2530
# 5        tt0000006            5.1       173
# 6        tt0000007            5.4       789
# ...            ...            ...       ...
# 1261687  tt9916204            8.1       245
# 1261694  tt9916348            8.5        17
# 1261695  tt9916362            6.4      4882
# 1261699  tt9916428            3.8        14
# 1261713  tt9916720            5.2       258
#
# [477310 rows x 3 columns]
